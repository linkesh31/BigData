# %%
# Import essential libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the preprocessed data
df = pd.read_csv('data/preprocessed_combined_dataset.csv')

# Display the first few rows to verify
print(df.head())
print(df.info())
# Out:
# C:\Users\linke\AppData\Local\Temp\ipykernel_13196\2110782189.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/preprocessed_combined_dataset.csv')
#     order_id  order_date    status  item_id                  sku  qty_ordered  \
# 0  100354678  2020-01-10  received   574772   oasis_Oasis-064-36          4.5
# 1  100354678  2020-01-10  received   574774      Fantastic_FT-48          4.5
# 2  100354680  2020-01-10  complete   574777      mdeal_DMC-610-8          4.5
# 3  100354680  2020-01-10  complete   574779   oasis_Oasis-061-36          4.5
# 4  100367357         NaN  received   595185  MEFNAR59C38B6CA08CD          2.0
#
#    price_x   value  discount_amount   total  ... productURL stars reviews  \
# 0     89.9  1798.0              0.0  1798.0  ...        NaN   NaN     NaN
# 1     19.0   190.0              0.0   190.0  ...        NaN   NaN     NaN
# 2    149.9  1199.2              0.0  1199.2  ...        NaN   NaN     NaN
# 3     79.9   639.2              0.0   639.2  ...        NaN   NaN     NaN
# 4     99.9    99.9              0.0    99.9  ...        NaN   NaN     NaN
#
#    price_y  listPrice category_id  isBestSeller boughtInLastMonth  id  \
# 0      NaN        NaN         NaN           NaN               NaN NaN
# 1      NaN        NaN         NaN           NaN               NaN NaN
# 2      NaN        NaN         NaN           NaN               NaN NaN
# 3      NaN        NaN         NaN           NaN               NaN NaN
# 4      NaN        NaN         NaN           NaN               NaN NaN
#
#   category_name
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 68 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286392 entries, 0 to 286391
# Data columns (total 68 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                286392 non-null  object
#  1   order_date              79948 non-null   object
#  2   status                  286392 non-null  object
#  3   item_id                 286392 non-null  int64
#  4   sku                     286392 non-null  object
#  5   qty_ordered             286392 non-null  float64
#  6   price_x                 286392 non-null  float64
#  7   value                   286392 non-null  float64
#  8   discount_amount         286392 non-null  float64
#  9   total                   286392 non-null  float64
#  10  category                286392 non-null  object
#  11  payment_method          286392 non-null  object
#  12  bi_st                   286392 non-null  object
#  13  cust_id                 286392 non-null  int64
#  14  year                    286392 non-null  int64
#  15  month                   286392 non-null  object
#  16  ref_num                 286392 non-null  int64
#  17  Name Prefix             286392 non-null  object
#  18  First Name              286392 non-null  object
#  19  Middle Initial          286392 non-null  object
#  20  Last Name               286392 non-null  object
#  21  Gender                  286392 non-null  object
#  22  age                     286392 non-null  int64
#  23  full_name               286392 non-null  object
#  24  E Mail                  286392 non-null  object
#  25  Sign in date            286392 non-null  object
#  26  Phone No.               286392 non-null  object
#  27  Place Name              286392 non-null  object
#  28  County                  286392 non-null  object
#  29  City_x                  286392 non-null  object
#  30  State_x                 286392 non-null  object
#  31  Zip                     286392 non-null  int64
#  32  Region_x                286392 non-null  object
#  33  User Name               286392 non-null  object
#  34  Discount_Percent        286392 non-null  float64
#  35  status_encoded          286392 non-null  int64
#  36  category_encoded        286392 non-null  int64
#  37  payment_method_encoded  286392 non-null  int64
#  38  Region_encoded_x        286392 non-null  int64
#  39  Order ID                0 non-null       float64
#  40  Order Date              0 non-null       float64
#  41  Customer Name           0 non-null       float64
#  42  City_y                  0 non-null       float64
#  43  Country                 0 non-null       float64
#  44  Region_y                0 non-null       float64
#  45  Segment                 0 non-null       float64
#  46  Ship Date               0 non-null       float64
#  47  Ship Mode               0 non-null       float64
#  48  State_y                 0 non-null       float64
#  49  Customer Name_encoded   0 non-null       float64
#  50  City_encoded            0 non-null       float64
#  51  Country_encoded         0 non-null       float64
#  52  Region_encoded_y        0 non-null       float64
#  53  Segment_encoded         0 non-null       float64
#  54  Ship Mode_encoded       0 non-null       float64
#  55  asin                    0 non-null       float64
#  56  title                   0 non-null       float64
#  57  imgUrl                  0 non-null       float64
#  58  productURL              0 non-null       float64
#  59  stars                   0 non-null       float64
#  60  reviews                 0 non-null       float64
#  61  price_y                 0 non-null       float64
#  62  listPrice               0 non-null       float64
#  63  category_id             0 non-null       float64
#  64  isBestSeller            0 non-null       float64
#  65  boughtInLastMonth       0 non-null       float64
#  66  id                      0 non-null       float64
#  67  category_name           0 non-null       float64
# dtypes: float64(35), int64(10), object(23)
# memory usage: 148.6+ MB
# None

# %%
# Define the features (X) and target variable (y)
X = df[['price_x', 'discount_amount', 'value']]  # Replace with relevant feature columns
y = df['qty_ordered']  # Target variable for regression

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Display the shapes of the splits to confirm
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (200474, 3)
# X_test shape: (85918, 3)
# y_train shape: (200474,)
# y_test shape: (85918,)

# %%
from sklearn.ensemble import RandomForestRegressor

# Initialize the Random Forest Regressor
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model
rf_model.fit(X_train, y_train)

print("Random Forest model training complete.")
# Out:
# Random Forest model training complete.

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Make predictions on the test set
y_pred_rf = rf_model.predict(X_test)

# Calculate Mean Squared Error (MSE) and R-Squared (R²)
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print(f'Random Forest Regressor - Mean Squared Error (MSE): {mse_rf}')
print(f'Random Forest Regressor - R-Squared (R²): {r2_rf}')
# Out:
# Random Forest Regressor - Mean Squared Error (MSE): 0.005097087739071412
# Random Forest Regressor - R-Squared (R²): 0.9940494864462995

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=y_pred_rf, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual Quantity Ordered')
plt.ylabel('Predicted Quantity Ordered')
plt.title('Actual vs Predicted Quantity Ordered (Random Forest)')
plt.show()
